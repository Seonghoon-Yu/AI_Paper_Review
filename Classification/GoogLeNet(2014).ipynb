# %% [markdown]
# <a href="https://colab.research.google.com/github/Seonghoon-Yu/paper-implement-in-pytorch/blob/master/Classification/GoogLeNet(2014).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('googlenet')
# Out:
# Mounted at googlenet

# %% [markdown]
# # 1. 데이터셋 불러오기
# 데이터셋은 torchvision 패키지에서 제공하는 STL10 dataset을 이용하겠습니다.
#
# STL10 dataset은 10개의 label을 갖습니다.

# %%
# import package

# model
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchsummary import summary
from torch import optim
from torch.optim.lr_scheduler import StepLR

# dataset and transformation
from torchvision import datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
import os

# display images
from torchvision import utils
import matplotlib.pyplot as plt
# %matplotlib inline

# utils
import numpy as np
from torchsummary import summary
import time
import copy

# %%
# specify the data path
path2data = '/content/googlenet/MyDrive/data'

# if not exists the path, make the directory
if not os.path.exists(path2data):
    os.mkdir(path2data)

# load dataset
train_ds = datasets.STL10(path2data, split='train', download=True, transform=transforms.ToTensor())
val_ds = datasets.STL10(path2data, split='test', download=True, transform=transforms.ToTensor())

print(len(train_ds))
print(len(val_ds))
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# 5000
# 8000

# %%
# To normalize the dataset, calculate the mean and std
train_meanRGB = [np.mean(x.numpy(), axis=(1,2)) for x, _ in train_ds]
train_stdRGB = [np.std(x.numpy(), axis=(1,2)) for x, _ in train_ds]

train_meanR = np.mean([m[0] for m in train_meanRGB])
train_meanG = np.mean([m[1] for m in train_meanRGB])
train_meanB = np.mean([m[2] for m in train_meanRGB])
train_stdR = np.mean([s[0] for s in train_stdRGB])
train_stdG = np.mean([s[1] for s in train_stdRGB])
train_stdB = np.mean([s[2] for s in train_stdRGB])


val_meanRGB = [np.mean(x.numpy(), axis=(1,2)) for x, _ in val_ds]
val_stdRGB = [np.std(x.numpy(), axis=(1,2)) for x, _ in val_ds]

val_meanR = np.mean([m[0] for m in val_meanRGB])
val_meanG = np.mean([m[1] for m in val_meanRGB])
val_meanB = np.mean([m[2] for m in val_meanRGB])

val_stdR = np.mean([s[0] for s in val_stdRGB])
val_stdG = np.mean([s[1] for s in val_stdRGB])
val_stdB = np.mean([s[2] for s in val_stdRGB])

print(train_meanR, train_meanG, train_meanB)
print(val_meanR, val_meanG, val_meanB)
# Out:
# 0.4467106 0.43980986 0.40664646
# 0.44723064 0.4396425 0.40495726

# %%
# define the image transformation
train_transformation = transforms.Compose([
                        transforms.ToTensor(),
                        transforms.Resize(224),
                        transforms.Normalize([train_meanR, train_meanG, train_meanB],[train_stdR, train_stdG, train_stdB]),
                        transforms.RandomHorizontalFlip(),
])

val_transformation = transforms.Compose([
                        transforms.ToTensor(),
                        transforms.Resize(224),
                        transforms.Normalize([train_meanR, train_meanG, train_meanB],[train_stdR, train_stdG, train_stdB]),
])

# apply transforamtion
train_ds.transform = train_transformation
val_ds.transform = val_transformation

# create DataLoader
train_dl = DataLoader(train_ds, batch_size=32, shuffle=True)
val_dl = DataLoader(val_ds, batch_size=32, shuffle=True)

# %%
# display sample images
def show(img, y=None, color=True):
    npimg = img.numpy()
    npimg_tr = np.transpose(npimg, (1, 2, 0))
    plt.imshow(npimg_tr)

    if y is not None:
        plt.title('labels: ' + str(y))

np.random.seed(0)
torch.manual_seed(0)

grid_size=4
rnd_inds=np.random.randint(0,len(train_ds),grid_size)
print("image indices:",rnd_inds)

x_grid=[train_ds[i][0] for i in rnd_inds]
y_grid=[train_ds[i][1] for i in rnd_inds]

x_grid=utils.make_grid(x_grid, nrow=4, padding=2)
print(x_grid.shape)

# call helper function
plt.figure(figsize=(10,10))
show(x_grid,y_grid)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# image indices: [2732 2607 1653 3264]
# torch.Size([3, 228, 906])

# %% [markdown]
# # 2. 모델 구축하기

# %%
class GoogLeNet(nn.Module):
    def __init__(self,aux_logits=True, num_classes=10, init_weights=True):
        super(GoogLeNet, self).__init__()
        assert aux_logits == True or aux_logits == False
        self.aux_logits = aux_logits

        # conv_block takes in_channels, out_channels, kernel_size, stride, padding
        # Inception block takes out1x1, red_3x3, out_3x3, red_5x5, out_5x5, out_1x1pool

        self.conv1 = conv_block(3, 64, kernel_size=7, stride=2, padding=3)
        self.maxpool1 = nn.MaxPool2d(3, 2, 1)
        self.conv2 = conv_block(64, 192, kernel_size=3, stride=1, padding=1)
        self.maxpool2 = nn.MaxPool2d(3, 2, 1)
        self.inception3a = Inception_block(192, 64, 96, 128, 16, 32, 32)
        self.inception3b = Inception_block(256, 128, 128, 192, 32, 96, 64)
        self.maxpool3 = nn.MaxPool2d(3, 2, 1)
        self.inception4a = Inception_block(480, 192, 96, 208, 16, 48, 64)

        # auxiliary classifier

        self.inception4b = Inception_block(512, 160, 112, 224, 24, 64, 64)
        self.inception4c = Inception_block(512, 128, 128, 256, 24, 64, 64)
        self.inception4d = Inception_block(512, 112, 144, 288, 32, 64, 64)

        # auxiliary classifier

        self.inception4e = Inception_block(528, 256, 160, 320, 32, 128, 128)
        self.maxpool4 = nn.MaxPool2d(3, 2, 1)
        self.inception5a = Inception_block(832, 256, 160, 320, 32, 128, 128)
        self.inception5b = Inception_block(832, 384, 192, 384, 48, 128, 128)

        self.avgpool = nn.AvgPool2d(7, 1)
        self.dropout = nn.Dropout(p=0.4)
        self.fc1 = nn.Linear(1024, num_classes)

        if self.aux_logits:
            self.aux1 = InceptionAux(512, num_classes)
            self.aux2 = InceptionAux(528, num_classes)
        else:
            self.aux1 = self.aux2 = None

        # weight initialization
        if init_weights:
            self._initialize_weights()

    def forward(self, x):
        x = self.conv1(x)
        x = self.maxpool1(x)
        x = self.conv2(x)
        x = self.maxpool2(x)
        x = self.inception3a(x)
        x = self.inception3b(x)
        x = self.maxpool3(x)
        x = self.inception4a(x)

        if self.aux_logits and self.training:
            aux1 = self.aux1(x)

        x = self.inception4b(x)
        x = self.inception4c(x)
        x = self.inception4d(x)

        if self.aux_logits and self.training:
            aux2 = self.aux2(x)

        x = self.inception4e(x)
        x = self.maxpool4(x)
        x = self.inception5a(x)
        x = self.inception5b(x)
        x = self.avgpool(x)

        x = x.view(x.shape[0], -1)

        x = self.dropout(x)
        x = self.fc1(x)

        if self.aux_logits and self.training:
            return x, aux1, aux2
        else:
            return x 

    # define weight initialization function
    def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')
                if m.bias is not None:
                    nn.init.constant_(m.bias, 0)
            elif isinstance(m, nn.BatchNorm2d):
                nn.init.constant_(m.weight, 1)
                nn.init.constant_(m.bias, 0)
            elif isinstance(m, nn.Linear):
                nn.init.normal_(m.weight, 0, 0.01)
                nn.init.constant_(m.bias, 0)

class conv_block(nn.Module):
    def __init__(self, in_channels, out_channels, **kwargs):
        super(conv_block, self).__init__()

        self.conv_layer = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, **kwargs),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(),
        )
    
    def forward(self, x):
        return self.conv_layer(x)


class Inception_block(nn.Module):
    def __init__(self, in_channels, out_1x1, red_3x3, out_3x3, red_5x5, out_5x5, out_1x1pool):
        super(Inception_block, self).__init__()

        self.branch1 = conv_block(in_channels, out_1x1, kernel_size=1)

        self.branch2 = nn.Sequential(
            conv_block(in_channels, red_3x3, kernel_size=1),
            conv_block(red_3x3, out_3x3, kernel_size=3, padding=1),
        )

        self.branch3 = nn.Sequential(
            conv_block(in_channels, red_5x5, kernel_size=1),
            conv_block(red_5x5, out_5x5, kernel_size=5, padding=2),
        )

        self.branch4 = nn.Sequential(
            nn.MaxPool2d(kernel_size=3, stride=1, padding=1),
            conv_block(in_channels, out_1x1pool, kernel_size=1)
        )

    def forward(self, x):
        # 0차원은 batch이므로 1차원인 filter 수를 기준으로 각 branch의 출력값을 묶어줍니다. 
        x = torch.cat([self.branch1(x), self.branch2(x), self.branch3(x), self.branch4(x)], 1)
        return x

# auxiliary classifier의 loss는 0.3이 곱해지고, 최종 loss에 추가합니다. 정규화 효과가 있습니다. 
class InceptionAux(nn.Module):
    def __init__(self, in_channels, num_classes):
        super(InceptionAux, self).__init__()

        self.conv = nn.Sequential(
            nn.AvgPool2d(kernel_size=5, stride=3),
            conv_block(in_channels, 128, kernel_size=1),
        )

        self.fc = nn.Sequential(
            nn.Linear(2048, 1024),
            nn.ReLU(),
            nn.Dropout(),
            nn.Linear(1024, num_classes),
        )

    def forward(self,x):
        x = self.conv(x)
        x = x.view(x.shape[0], -1)
        x = self.fc(x)
        return x

# %%
x = torch.randn(3, 3, 224, 224).to(device)
output = model(x)
print(output)
# Out:
# tensor([[ 0.3884,  1.0438, -2.9496,  0.3850, -1.3615, -0.1870,  1.1378, -3.0826,
#           1.8468, -2.8689],
#         [ 0.5371,  0.9480, -2.6056,  0.4280, -1.4506,  0.0583,  0.8462, -2.5828,
#           1.9604, -3.0983],
#         [-0.0394,  1.4182, -2.4758,  0.2987, -1.4623, -0.0552,  0.8802, -2.8736,
#           1.5914, -2.8920]], device='cuda:0', grad_fn=<AddmmBackward>)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)

model = GoogLeNet(aux_logits=True, num_classes=10, init_weights=True).to(device)
print(model)
# Out:
# cuda
# GoogLeNet(
#   (conv1): conv_block(
#     (conv_layer): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#   )
#   (maxpool1): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (conv2): conv_block(
#     (conv_layer): Sequential(
#       (0): Conv2d(64, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#   )
#   (maxpool2): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (inception3a): Inception_block(
#     (branch1): conv_block(
#       (conv_layer): Sequential(
#         (0): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1))
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#       )
#     )
#     (branch2): Sequential(
#       (0): conv_block(
#         (conv_layer): Sequential(
#           (0): Conv2d(192, 96, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#       )
#       (1): conv_block(
#         (conv_layer): Sequential(
#           (0): Conv2d(96, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#       )
#     )
#     (branch3): Sequential(
#       (0): conv_block(
#         (conv_layer): Sequential(
#           (0): Conv2d(192, 16, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#       )
#       (1): conv_block(
#         (conv_layer): Sequential(
#           (0): Conv2d(16, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (1): conv_block(
#         (conv_layer): Sequential(
#           (0): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#       )
#     )
#   )
#   (inception3b): Inception_block(
#     (branch1): conv_block(
#       (conv_layer): Sequential(
#         (0): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#       )
#     )
#     (branch2): Sequential(
#       (0): conv_block(
#         (conv_layer): Sequential(
#           (0): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#       )
#       (1): conv_block(
#         (conv_layer): Sequential(
#           (0): Conv2d(128, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#       )
#     )
#     (branch3): Sequential(
#       (0): conv_block(
#         (conv_layer): Sequential(
#           (0): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#       )
#       (1): conv_block(
#         (conv_layer): Sequential(
#           (0): Conv2d(32, 96, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#           (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (1): conv_block(
#         (conv_layer): Sequential(
#           (0): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#       )
#     )
#   )
#   (maxpool3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (inception4a): Inception_block(
#     (branch1): conv_block(
#       (conv_layer): Sequential(
#         (0): Conv2d(480, 192, kernel_size=(1, 1), stride=(1, 1))
#         (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#       )
#     )
#     (branch2): Sequential(
#       (0): conv_block(
#         (conv_layer): Sequential(
#           (0): Conv2d(480, 96, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#       )
#       (1): conv_block(
#         (conv_layer): Sequential(
#           (0): Conv2d(96, 208, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): BatchNorm2d(208, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#       )
#     )
#     (branch3): Sequential(
#       (0): conv_block(
#         (conv_layer): Sequential(
#           (0): Conv2d(480, 16, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#       )
#       (1): conv_block(
#         (conv_layer): Sequential(
#           (0): Conv2d(16, 48, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#           (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (1): conv_block(
#         (conv_layer): Sequential(
#           (0): Conv2d(480, 64, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#       )
#     )
#   )
#   (inception4b): Inception_block(
#     (branch1): conv_block(
#       (conv_layer): Sequential(
#         (0): Conv2d(512, 160, kernel_size=(1, 1), stride=(1, 1))
#         (1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#       )
#     )
#     (branch2): Sequential(
#       (0): conv_block(
#         (conv_layer): Sequential(
#           (0): Conv2d(512, 112, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#       )
#       (1): conv_block(
#         (conv_layer): Sequential(
#           (0): Conv2d(112, 224, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#       )
#     )
#     (branch3): Sequential(
#       (0): conv_block(
#         (conv_layer): Sequential(
#           (0): Conv2d(512, 24, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#       )
#       (1): conv_block(
#         (conv_layer): Sequential(
#           (0): Conv2d(24, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (1): conv_block(
#         (conv_layer): Sequential(
#           (0): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#       )
#     )
#   )
#   (inception4c): Inception_block(
#     (branch1): conv_block(
#       (conv_layer): Sequential(
#         (0): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#       )
#     )
#     (branch2): Sequential(
#       (0): conv_block(
#         (conv_layer): Sequential(
#           (0): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#       )
#       (1): conv_block(
#         (conv_layer): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#       )
#     )
#     (branch3): Sequential(
#       (0): conv_block(
#         (conv_layer): Sequential(
#           (0): Conv2d(512, 24, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#       )
#       (1): conv_block(
#         (conv_layer): Sequential(
#           (0): Conv2d(24, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (1): conv_block(
#         (conv_layer): Sequential(
#           (0): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#       )
#     )
#   )
#   (inception4d): Inception_block(
#     (branch1): conv_block(
#       (conv_layer): Sequential(
#         (0): Conv2d(512, 112, kernel_size=(1, 1), stride=(1, 1))
#         (1): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#       )
#     )
#     (branch2): Sequential(
#       (0): conv_block(
#         (conv_layer): Sequential(
#           (0): Conv2d(512, 144, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#       )
#       (1): conv_block(
#         (conv_layer): Sequential(
#           (0): Conv2d(144, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#       )
#     )
#     (branch3): Sequential(
#       (0): conv_block(
#         (conv_layer): Sequential(
#           (0): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#       )
#       (1): conv_block(
#         (conv_layer): Sequential(
#           (0): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (1): conv_block(
#         (conv_layer): Sequential(
#           (0): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#       )
#     )
#   )
#   (inception4e): Inception_block(
#     (branch1): conv_block(
#       (conv_layer): Sequential(
#         (0): Conv2d(528, 256, kernel_size=(1, 1), stride=(1, 1))
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#       )
#     )
#     (branch2): Sequential(
#       (0): conv_block(
#         (conv_layer): Sequential(
#           (0): Conv2d(528, 160, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#       )
#       (1): conv_block(
#         (conv_layer): Sequential(
#           (0): Conv2d(160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#       )
#     )
#     (branch3): Sequential(
#       (0): conv_block(
#         (conv_layer): Sequential(
#           (0): Conv2d(528, 32, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#       )
#       (1): conv_block(
#         (conv_layer): Sequential(
#           (0): Conv2d(32, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (1): conv_block(
#         (conv_layer): Sequential(
#           (0): Conv2d(528, 128, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#       )
#     )
#   )
#   (maxpool4): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (inception5a): Inception_block(
#     (branch1): conv_block(
#       (conv_layer): Sequential(
#         (0): Conv2d(832, 256, kernel_size=(1, 1), stride=(1, 1))
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#       )
#     )
#     (branch2): Sequential(
#       (0): conv_block(
#         (conv_layer): Sequential(
#           (0): Conv2d(832, 160, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#       )
#       (1): conv_block(
#         (conv_layer): Sequential(
#           (0): Conv2d(160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#       )
#     )
#     (branch3): Sequential(
#       (0): conv_block(
#         (conv_layer): Sequential(
#           (0): Conv2d(832, 32, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#       )
#       (1): conv_block(
#         (conv_layer): Sequential(
#           (0): Conv2d(32, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (1): conv_block(
#         (conv_layer): Sequential(
#           (0): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#       )
#     )
#   )
#   (inception5b): Inception_block(
#     (branch1): conv_block(
#       (conv_layer): Sequential(
#         (0): Conv2d(832, 384, kernel_size=(1, 1), stride=(1, 1))
#         (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#       )
#     )
#     (branch2): Sequential(
#       (0): conv_block(
#         (conv_layer): Sequential(
#           (0): Conv2d(832, 192, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#       )
#       (1): conv_block(
#         (conv_layer): Sequential(
#           (0): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#       )
#     )
#     (branch3): Sequential(
#       (0): conv_block(
#         (conv_layer): Sequential(
#           (0): Conv2d(832, 48, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#       )
#       (1): conv_block(
#         (conv_layer): Sequential(
#           (0): Conv2d(48, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (1): conv_block(
#         (conv_layer): Sequential(
#           (0): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#       )
#     )
#   )
#   (avgpool): AvgPool2d(kernel_size=7, stride=1, padding=0)
#   (dropout): Dropout(p=0.4, inplace=False)
#   (fc1): Linear(in_features=1024, out_features=10, bias=True)
#   (aux1): InceptionAux(
#     (conv): Sequential(
#       (0): AvgPool2d(kernel_size=5, stride=3, padding=0)
#       (1): conv_block(
#         (conv_layer): Sequential(
#           (0): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#       )
#     )
#     (fc): Sequential(
#       (0): Linear(in_features=2048, out_features=1024, bias=True)
#       (1): ReLU()
#       (2): Dropout(p=0.5, inplace=False)
#       (3): Linear(in_features=1024, out_features=10, bias=True)
#     )
#   )
#   (aux2): InceptionAux(
#     (conv): Sequential(
#       (0): AvgPool2d(kernel_size=5, stride=3, padding=0)
#       (1): conv_block(
#         (conv_layer): Sequential(
#           (0): Conv2d(528, 128, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#       )
#     )
#     (fc): Sequential(
#       (0): Linear(in_features=2048, out_features=1024, bias=True)
#       (1): ReLU()
#       (2): Dropout(p=0.5, inplace=False)
#       (3): Linear(in_features=1024, out_features=10, bias=True)
#     )
#   )
# )

# %%
summary(model, input_size=(3,224,224), device=device.type)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 112, 112]           9,472
#        BatchNorm2d-2         [-1, 64, 112, 112]             128
#               ReLU-3         [-1, 64, 112, 112]               0
#         conv_block-4         [-1, 64, 112, 112]               0
#          MaxPool2d-5           [-1, 64, 56, 56]               0
#             Conv2d-6          [-1, 192, 56, 56]         110,784
#        BatchNorm2d-7          [-1, 192, 56, 56]             384
#               ReLU-8          [-1, 192, 56, 56]               0
#         conv_block-9          [-1, 192, 56, 56]               0
#         MaxPool2d-10          [-1, 192, 28, 28]               0
#            Conv2d-11           [-1, 64, 28, 28]          12,352
#       BatchNorm2d-12           [-1, 64, 28, 28]             128
#              ReLU-13           [-1, 64, 28, 28]               0
#        conv_block-14           [-1, 64, 28, 28]               0
#            Conv2d-15           [-1, 96, 28, 28]          18,528
#       BatchNorm2d-16           [-1, 96, 28, 28]             192
#              ReLU-17           [-1, 96, 28, 28]               0
#        conv_block-18           [-1, 96, 28, 28]               0
#            Conv2d-19          [-1, 128, 28, 28]         110,720
#       BatchNorm2d-20          [-1, 128, 28, 28]             256
#              ReLU-21          [-1, 128, 28, 28]               0
#        conv_block-22          [-1, 128, 28, 28]               0
#            Conv2d-23           [-1, 16, 28, 28]           3,088
#       BatchNorm2d-24           [-1, 16, 28, 28]              32
#              ReLU-25           [-1, 16, 28, 28]               0
#        conv_block-26           [-1, 16, 28, 28]               0
#            Conv2d-27           [-1, 32, 28, 28]          12,832
#       BatchNorm2d-28           [-1, 32, 28, 28]              64
#              ReLU-29           [-1, 32, 28, 28]               0
#        conv_block-30           [-1, 32, 28, 28]               0
#         MaxPool2d-31          [-1, 192, 28, 28]               0
#            Conv2d-32           [-1, 32, 28, 28]           6,176
#       BatchNorm2d-33           [-1, 32, 28, 28]              64
#              ReLU-34           [-1, 32, 28, 28]               0
#        conv_block-35           [-1, 32, 28, 28]               0
#   Inception_block-36          [-1, 256, 28, 28]               0
#            Conv2d-37          [-1, 128, 28, 28]          32,896
#       BatchNorm2d-38          [-1, 128, 28, 28]             256
#              ReLU-39          [-1, 128, 28, 28]               0
#        conv_block-40          [-1, 128, 28, 28]               0
#            Conv2d-41          [-1, 128, 28, 28]          32,896
#       BatchNorm2d-42          [-1, 128, 28, 28]             256
#              ReLU-43          [-1, 128, 28, 28]               0
#        conv_block-44          [-1, 128, 28, 28]               0
#            Conv2d-45          [-1, 192, 28, 28]         221,376
#       BatchNorm2d-46          [-1, 192, 28, 28]             384
#              ReLU-47          [-1, 192, 28, 28]               0
#        conv_block-48          [-1, 192, 28, 28]               0
#            Conv2d-49           [-1, 32, 28, 28]           8,224
#       BatchNorm2d-50           [-1, 32, 28, 28]              64
#              ReLU-51           [-1, 32, 28, 28]               0
#        conv_block-52           [-1, 32, 28, 28]               0
#            Conv2d-53           [-1, 96, 28, 28]          76,896
#       BatchNorm2d-54           [-1, 96, 28, 28]             192
#              ReLU-55           [-1, 96, 28, 28]               0
#        conv_block-56           [-1, 96, 28, 28]               0
#         MaxPool2d-57          [-1, 256, 28, 28]               0
#            Conv2d-58           [-1, 64, 28, 28]          16,448
#       BatchNorm2d-59           [-1, 64, 28, 28]             128
#              ReLU-60           [-1, 64, 28, 28]               0
#        conv_block-61           [-1, 64, 28, 28]               0
#   Inception_block-62          [-1, 480, 28, 28]               0
#         MaxPool2d-63          [-1, 480, 14, 14]               0
#            Conv2d-64          [-1, 192, 14, 14]          92,352
#       BatchNorm2d-65          [-1, 192, 14, 14]             384
#              ReLU-66          [-1, 192, 14, 14]               0
#        conv_block-67          [-1, 192, 14, 14]               0
#            Conv2d-68           [-1, 96, 14, 14]          46,176
#       BatchNorm2d-69           [-1, 96, 14, 14]             192
#              ReLU-70           [-1, 96, 14, 14]               0
#        conv_block-71           [-1, 96, 14, 14]               0
#            Conv2d-72          [-1, 208, 14, 14]         179,920
#       BatchNorm2d-73          [-1, 208, 14, 14]             416
#              ReLU-74          [-1, 208, 14, 14]               0
#        conv_block-75          [-1, 208, 14, 14]               0
#            Conv2d-76           [-1, 16, 14, 14]           7,696
#       BatchNorm2d-77           [-1, 16, 14, 14]              32
#              ReLU-78           [-1, 16, 14, 14]               0
#        conv_block-79           [-1, 16, 14, 14]               0
#            Conv2d-80           [-1, 48, 14, 14]          19,248
#       BatchNorm2d-81           [-1, 48, 14, 14]              96
#              ReLU-82           [-1, 48, 14, 14]               0
#        conv_block-83           [-1, 48, 14, 14]               0
#         MaxPool2d-84          [-1, 480, 14, 14]               0
#            Conv2d-85           [-1, 64, 14, 14]          30,784
#       BatchNorm2d-86           [-1, 64, 14, 14]             128
#              ReLU-87           [-1, 64, 14, 14]               0
#        conv_block-88           [-1, 64, 14, 14]               0
#   Inception_block-89          [-1, 512, 14, 14]               0
#         AvgPool2d-90            [-1, 512, 4, 4]               0
#            Conv2d-91            [-1, 128, 4, 4]          65,664
#       BatchNorm2d-92            [-1, 128, 4, 4]             256
#              ReLU-93            [-1, 128, 4, 4]               0
#        conv_block-94            [-1, 128, 4, 4]               0
#            Linear-95                 [-1, 1024]       2,098,176
#              ReLU-96                 [-1, 1024]               0
#           Dropout-97                 [-1, 1024]               0
#            Linear-98                   [-1, 10]          10,250
#      InceptionAux-99                   [-1, 10]               0
#           Conv2d-100          [-1, 160, 14, 14]          82,080
#      BatchNorm2d-101          [-1, 160, 14, 14]             320
#             ReLU-102          [-1, 160, 14, 14]               0
#       conv_block-103          [-1, 160, 14, 14]               0
#           Conv2d-104          [-1, 112, 14, 14]          57,456
#      BatchNorm2d-105          [-1, 112, 14, 14]             224
#             ReLU-106          [-1, 112, 14, 14]               0
#       conv_block-107          [-1, 112, 14, 14]               0
#           Conv2d-108          [-1, 224, 14, 14]         226,016
#      BatchNorm2d-109          [-1, 224, 14, 14]             448
#             ReLU-110          [-1, 224, 14, 14]               0
#       conv_block-111          [-1, 224, 14, 14]               0
#           Conv2d-112           [-1, 24, 14, 14]          12,312
#      BatchNorm2d-113           [-1, 24, 14, 14]              48
#             ReLU-114           [-1, 24, 14, 14]               0
#       conv_block-115           [-1, 24, 14, 14]               0
#           Conv2d-116           [-1, 64, 14, 14]          38,464
#      BatchNorm2d-117           [-1, 64, 14, 14]             128
#             ReLU-118           [-1, 64, 14, 14]               0
#       conv_block-119           [-1, 64, 14, 14]               0
#        MaxPool2d-120          [-1, 512, 14, 14]               0
#           Conv2d-121           [-1, 64, 14, 14]          32,832
#      BatchNorm2d-122           [-1, 64, 14, 14]             128
#             ReLU-123           [-1, 64, 14, 14]               0
#       conv_block-124           [-1, 64, 14, 14]               0
#  Inception_block-125          [-1, 512, 14, 14]               0
#           Conv2d-126          [-1, 128, 14, 14]          65,664
#      BatchNorm2d-127          [-1, 128, 14, 14]             256
#             ReLU-128          [-1, 128, 14, 14]               0
#       conv_block-129          [-1, 128, 14, 14]               0
#           Conv2d-130          [-1, 128, 14, 14]          65,664
#      BatchNorm2d-131          [-1, 128, 14, 14]             256
#             ReLU-132          [-1, 128, 14, 14]               0
#       conv_block-133          [-1, 128, 14, 14]               0
#           Conv2d-134          [-1, 256, 14, 14]         295,168
#      BatchNorm2d-135          [-1, 256, 14, 14]             512
#             ReLU-136          [-1, 256, 14, 14]               0
#       conv_block-137          [-1, 256, 14, 14]               0
#           Conv2d-138           [-1, 24, 14, 14]          12,312
#      BatchNorm2d-139           [-1, 24, 14, 14]              48
#             ReLU-140           [-1, 24, 14, 14]               0
#       conv_block-141           [-1, 24, 14, 14]               0
#           Conv2d-142           [-1, 64, 14, 14]          38,464
#      BatchNorm2d-143           [-1, 64, 14, 14]             128
#             ReLU-144           [-1, 64, 14, 14]               0
#       conv_block-145           [-1, 64, 14, 14]               0
#        MaxPool2d-146          [-1, 512, 14, 14]               0
#           Conv2d-147           [-1, 64, 14, 14]          32,832
#      BatchNorm2d-148           [-1, 64, 14, 14]             128
#             ReLU-149           [-1, 64, 14, 14]               0
#       conv_block-150           [-1, 64, 14, 14]               0
#  Inception_block-151          [-1, 512, 14, 14]               0
#           Conv2d-152          [-1, 112, 14, 14]          57,456
#      BatchNorm2d-153          [-1, 112, 14, 14]             224
#             ReLU-154          [-1, 112, 14, 14]               0
#       conv_block-155          [-1, 112, 14, 14]               0
#           Conv2d-156          [-1, 144, 14, 14]          73,872
#      BatchNorm2d-157          [-1, 144, 14, 14]             288
#             ReLU-158          [-1, 144, 14, 14]               0
#       conv_block-159          [-1, 144, 14, 14]               0
#           Conv2d-160          [-1, 288, 14, 14]         373,536
#      BatchNorm2d-161          [-1, 288, 14, 14]             576
#             ReLU-162          [-1, 288, 14, 14]               0
#       conv_block-163          [-1, 288, 14, 14]               0
#           Conv2d-164           [-1, 32, 14, 14]          16,416
#      BatchNorm2d-165           [-1, 32, 14, 14]              64
#             ReLU-166           [-1, 32, 14, 14]               0
#       conv_block-167           [-1, 32, 14, 14]               0
#           Conv2d-168           [-1, 64, 14, 14]          51,264
#      BatchNorm2d-169           [-1, 64, 14, 14]             128
#             ReLU-170           [-1, 64, 14, 14]               0
#       conv_block-171           [-1, 64, 14, 14]               0
#        MaxPool2d-172          [-1, 512, 14, 14]               0
#           Conv2d-173           [-1, 64, 14, 14]          32,832
#      BatchNorm2d-174           [-1, 64, 14, 14]             128
#             ReLU-175           [-1, 64, 14, 14]               0
#       conv_block-176           [-1, 64, 14, 14]               0
#  Inception_block-177          [-1, 528, 14, 14]               0
#        AvgPool2d-178            [-1, 528, 4, 4]               0
#           Conv2d-179            [-1, 128, 4, 4]          67,712
#      BatchNorm2d-180            [-1, 128, 4, 4]             256
#             ReLU-181            [-1, 128, 4, 4]               0
#       conv_block-182            [-1, 128, 4, 4]               0
#           Linear-183                 [-1, 1024]       2,098,176
#             ReLU-184                 [-1, 1024]               0
#          Dropout-185                 [-1, 1024]               0
#           Linear-186                   [-1, 10]          10,250
#     InceptionAux-187                   [-1, 10]               0
#           Conv2d-188          [-1, 256, 14, 14]         135,424
#      BatchNorm2d-189          [-1, 256, 14, 14]             512
#             ReLU-190          [-1, 256, 14, 14]               0
#       conv_block-191          [-1, 256, 14, 14]               0
#           Conv2d-192          [-1, 160, 14, 14]          84,640
#      BatchNorm2d-193          [-1, 160, 14, 14]             320
#             ReLU-194          [-1, 160, 14, 14]               0
#       conv_block-195          [-1, 160, 14, 14]               0
#           Conv2d-196          [-1, 320, 14, 14]         461,120
#      BatchNorm2d-197          [-1, 320, 14, 14]             640
#             ReLU-198          [-1, 320, 14, 14]               0
#       conv_block-199          [-1, 320, 14, 14]               0
#           Conv2d-200           [-1, 32, 14, 14]          16,928
#      BatchNorm2d-201           [-1, 32, 14, 14]              64
#             ReLU-202           [-1, 32, 14, 14]               0
#       conv_block-203           [-1, 32, 14, 14]               0
#           Conv2d-204          [-1, 128, 14, 14]         102,528
#      BatchNorm2d-205          [-1, 128, 14, 14]             256
#             ReLU-206          [-1, 128, 14, 14]               0
#       conv_block-207          [-1, 128, 14, 14]               0
#        MaxPool2d-208          [-1, 528, 14, 14]               0
#           Conv2d-209          [-1, 128, 14, 14]          67,712
#      BatchNorm2d-210          [-1, 128, 14, 14]             256
#             ReLU-211          [-1, 128, 14, 14]               0
#       conv_block-212          [-1, 128, 14, 14]               0
#  Inception_block-213          [-1, 832, 14, 14]               0
#        MaxPool2d-214            [-1, 832, 7, 7]               0
#           Conv2d-215            [-1, 256, 7, 7]         213,248
#      BatchNorm2d-216            [-1, 256, 7, 7]             512
#             ReLU-217            [-1, 256, 7, 7]               0
#       conv_block-218            [-1, 256, 7, 7]               0
#           Conv2d-219            [-1, 160, 7, 7]         133,280
#      BatchNorm2d-220            [-1, 160, 7, 7]             320
#             ReLU-221            [-1, 160, 7, 7]               0
#       conv_block-222            [-1, 160, 7, 7]               0
#           Conv2d-223            [-1, 320, 7, 7]         461,120
#      BatchNorm2d-224            [-1, 320, 7, 7]             640
#             ReLU-225            [-1, 320, 7, 7]               0
#       conv_block-226            [-1, 320, 7, 7]               0
#           Conv2d-227             [-1, 32, 7, 7]          26,656
#      BatchNorm2d-228             [-1, 32, 7, 7]              64
#             ReLU-229             [-1, 32, 7, 7]               0
#       conv_block-230             [-1, 32, 7, 7]               0
#           Conv2d-231            [-1, 128, 7, 7]         102,528
#      BatchNorm2d-232            [-1, 128, 7, 7]             256
#             ReLU-233            [-1, 128, 7, 7]               0
#       conv_block-234            [-1, 128, 7, 7]               0
#        MaxPool2d-235            [-1, 832, 7, 7]               0
#           Conv2d-236            [-1, 128, 7, 7]         106,624
#      BatchNorm2d-237            [-1, 128, 7, 7]             256
#             ReLU-238            [-1, 128, 7, 7]               0
#       conv_block-239            [-1, 128, 7, 7]               0
#  Inception_block-240            [-1, 832, 7, 7]               0
#           Conv2d-241            [-1, 384, 7, 7]         319,872
#      BatchNorm2d-242            [-1, 384, 7, 7]             768
#             ReLU-243            [-1, 384, 7, 7]               0
#       conv_block-244            [-1, 384, 7, 7]               0
#           Conv2d-245            [-1, 192, 7, 7]         159,936
#      BatchNorm2d-246            [-1, 192, 7, 7]             384
#             ReLU-247            [-1, 192, 7, 7]               0
#       conv_block-248            [-1, 192, 7, 7]               0
#           Conv2d-249            [-1, 384, 7, 7]         663,936
#      BatchNorm2d-250            [-1, 384, 7, 7]             768
#             ReLU-251            [-1, 384, 7, 7]               0
#       conv_block-252            [-1, 384, 7, 7]               0
#           Conv2d-253             [-1, 48, 7, 7]          39,984
#      BatchNorm2d-254             [-1, 48, 7, 7]              96
#             ReLU-255             [-1, 48, 7, 7]               0
#       conv_block-256             [-1, 48, 7, 7]               0
#           Conv2d-257            [-1, 128, 7, 7]         153,728
#      BatchNorm2d-258            [-1, 128, 7, 7]             256
#             ReLU-259            [-1, 128, 7, 7]               0
#       conv_block-260            [-1, 128, 7, 7]               0
#        MaxPool2d-261            [-1, 832, 7, 7]               0
#           Conv2d-262            [-1, 128, 7, 7]         106,624
#      BatchNorm2d-263            [-1, 128, 7, 7]             256
#             ReLU-264            [-1, 128, 7, 7]               0
#       conv_block-265            [-1, 128, 7, 7]               0
#  Inception_block-266           [-1, 1024, 7, 7]               0
#        AvgPool2d-267           [-1, 1024, 1, 1]               0
#          Dropout-268                 [-1, 1024]               0
#           Linear-269                   [-1, 10]          10,250
# ================================================================
# Total params: 10,344,814
# Trainable params: 10,344,814
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 112.89
# Params size (MB): 39.46
# Estimated Total Size (MB): 152.92
# ----------------------------------------------------------------

# %% [markdown]
# # 3. 학습하기

# %%
loss_func = nn.CrossEntropyLoss(reduction='sum')
opt = optim.Adam(model.parameters(), lr=0.001)

from torch.optim.lr_scheduler import StepLR
lr_scheduler = StepLR(opt, step_size=30, gamma=0.1)

def get_lr(opt):
    for param_group in opt.param_groups:
        return param_group['lr']



def metric_batch(output, target):
    pred = output.argmax(dim=1, keepdim=True)
    corrects = pred.eq(target.view_as(pred)).sum().item()
    return corrects



def loss_batch(loss_func, outputs, target, opt=None):
    if np.shape(outputs)[0] == 3:
        output, aux1, aux2 = outputs

        output_loss = loss_func(output, target)
        aux1_loss = loss_func(aux1, target)
        aux2_loss = loss_func(aux2, target)

        loss = output_loss + 0.3*(aux1_loss + aux2_loss)
        metric_b = metric_batch(output,target)

    else:
        loss = loss_func(outputs, target)
        metric_b = metric_batch(outputs, target)

    if opt is not None:
        opt.zero_grad()
        loss.backward()
        opt.step()
    
    return loss.item(), metric_b



def loss_epoch(model, loss_func, dataset_dl, sanity_check=False, opt=None):
    running_loss = 0.0
    running_metric = 0.0
    len_data = len(dataset_dl.dataset)

    for xb, yb in dataset_dl:
        xb = xb.to(device)
        yb = yb.to(device)
        output= model(xb)

        loss_b, metric_b = loss_batch(loss_func, output, yb, opt)

        running_loss += loss_b

        if metric_b is not None:
            running_metric += metric_b
        
        if sanity_check is True:
            break

    loss = running_loss / len_data
    metric = running_metric / len_data

    return loss, metric



def train_val(model, params):
    num_epochs=params["num_epochs"]
    loss_func=params["loss_func"]
    opt=params["optimizer"]
    train_dl=params["train_dl"]
    val_dl=params["val_dl"]
    sanity_check=params["sanity_check"]
    lr_scheduler=params["lr_scheduler"]
    path2weights=params["path2weights"]

    loss_history = {'train': [], 'val': []}
    metric_history = {'train': [], 'val': []}

    best_model_wts = copy.deepcopy(model.state_dict())

    best_loss = float('inf')
    
    start_time = time.time()
    for epoch in range(num_epochs):
        current_lr = get_lr(opt)
        print('Epoch {}/{}, current lr={}'.format(epoch, num_epochs - 1, current_lr))
        
        model.train()
        train_loss, train_metric = loss_epoch(model, loss_func, train_dl, sanity_check, opt)
        loss_history['train'].append(train_loss)
        metric_history['train'].append(train_metric)

        model.eval()
        with torch.no_grad():
            val_loss, val_metric = loss_epoch(model, loss_func, val_dl, sanity_check)

        if val_loss < best_loss:
            best_loss = val_loss
            best_model_wts = copy.deepcopy(model.state_dict())

            torch.save(model.state_dict(), path2weights)
            print('Copied best model weights!')

        loss_history['val'].append(val_loss)
        metric_history['val'].append(val_metric)

        lr_scheduler.step()

        print('train loss: %.6f, val loss: %.6f, accuracy: %.2f, time: %.4f min' %(train_loss, val_loss, 100*val_metric, (time.time()-start_time)/60))
        print('-'*10)

    model.load_state_dict(best_model_wts)

    return model, loss_history, metric_history

# %%
# definc the training parameters
params_train = {
    'num_epochs':100,
    'optimizer':opt,
    'loss_func':loss_func,
    'train_dl':train_dl,
    'val_dl':val_dl,
    'sanity_check':False,
    'lr_scheduler':lr_scheduler,
    'path2weights':'./models/weights.pt',
}

# create the directory that stores weights.pt
def createFolder(directory):
    try:
        if not os.path.exists(directory):
            os.makedirs(directory)
    except OSerror:
        print('Error')
createFolder('./models')

# %%
model, loss_hist, metric_hist = train_val(model, params_train)
# Out:
# Epoch 0/99, current lr=0.001
# Copied best model weights!
# train loss: 2.779700, val loss: 2.126027, accuracy: 29.84, time: 1.8985 min
# ----------
# Epoch 1/99, current lr=0.001
# Copied best model weights!
# train loss: 2.382252, val loss: 1.778976, accuracy: 38.38, time: 3.8028 min
# ----------
# Epoch 2/99, current lr=0.001
# Copied best model weights!
# train loss: 2.117530, val loss: 1.600303, accuracy: 41.76, time: 5.7054 min
# ----------
# Epoch 3/99, current lr=0.001
# Copied best model weights!
# train loss: 1.871930, val loss: 1.567426, accuracy: 48.36, time: 7.6135 min
# ----------
# Epoch 4/99, current lr=0.001
# Copied best model weights!
# train loss: 1.692343, val loss: 1.209519, accuracy: 57.01, time: 9.5257 min
# ----------
# Epoch 5/99, current lr=0.001
# Copied best model weights!
# train loss: 1.539148, val loss: 1.132288, accuracy: 60.22, time: 11.4310 min
# ----------
# Epoch 6/99, current lr=0.001
# train loss: 1.431928, val loss: 1.183061, accuracy: 58.81, time: 13.3342 min
# ----------
# Epoch 7/99, current lr=0.001
# train loss: 1.258715, val loss: 1.244081, accuracy: 57.80, time: 15.2511 min
# ----------
# Epoch 8/99, current lr=0.001
# train loss: 1.190642, val loss: 1.162667, accuracy: 61.66, time: 17.1654 min
# ----------
# Epoch 9/99, current lr=0.001
# Copied best model weights!
# train loss: 1.036331, val loss: 0.951480, accuracy: 68.51, time: 19.0705 min
# ----------
# Epoch 10/99, current lr=0.001
# train loss: 0.984557, val loss: 1.100568, accuracy: 65.46, time: 20.9629 min
# ----------
# Epoch 11/99, current lr=0.001
# train loss: 0.899106, val loss: 1.280019, accuracy: 61.32, time: 22.8733 min
# ----------
# Epoch 12/99, current lr=0.001
# train loss: 0.821357, val loss: 1.067569, accuracy: 66.20, time: 24.7797 min
# ----------
# Epoch 13/99, current lr=0.001
# train loss: 0.759625, val loss: 1.054473, accuracy: 68.39, time: 26.6815 min
# ----------
# Epoch 14/99, current lr=0.001
# train loss: 0.665149, val loss: 1.018657, accuracy: 69.44, time: 28.5768 min
# ----------
# Epoch 15/99, current lr=0.001
# train loss: 0.645300, val loss: 1.000523, accuracy: 69.90, time: 30.4976 min
# ----------
# Epoch 16/99, current lr=0.001
# train loss: 0.508037, val loss: 1.034666, accuracy: 70.23, time: 32.4522 min
# ----------
# Epoch 17/99, current lr=0.001
# train loss: 0.455679, val loss: 1.081046, accuracy: 69.60, time: 34.3755 min
# ----------
# Epoch 18/99, current lr=0.001
# train loss: 0.432060, val loss: 1.179201, accuracy: 68.77, time: 36.2854 min
# ----------
# Epoch 19/99, current lr=0.001
# train loss: 0.427230, val loss: 1.047111, accuracy: 70.96, time: 38.1983 min
# ----------
# Epoch 20/99, current lr=0.001
# train loss: 0.324731, val loss: 1.230285, accuracy: 70.20, time: 40.1062 min
# ----------
# Epoch 21/99, current lr=0.001
# train loss: 0.309340, val loss: 1.215371, accuracy: 71.44, time: 42.0125 min
# ----------
# Epoch 22/99, current lr=0.001
# train loss: 0.277689, val loss: 1.214809, accuracy: 71.09, time: 43.9109 min
# ----------
# Epoch 23/99, current lr=0.001
# train loss: 0.263676, val loss: 1.143686, accuracy: 72.52, time: 45.8079 min
# ----------
# Epoch 24/99, current lr=0.001
# train loss: 0.274344, val loss: 1.063270, accuracy: 73.40, time: 47.7150 min
# ----------
# Epoch 25/99, current lr=0.001
# train loss: 0.239316, val loss: 1.207171, accuracy: 71.33, time: 49.6330 min
# ----------
# Epoch 26/99, current lr=0.001
# train loss: 0.244422, val loss: 1.222819, accuracy: 71.74, time: 51.5391 min
# ----------
# Epoch 27/99, current lr=0.001
# train loss: 0.205428, val loss: 1.279880, accuracy: 71.75, time: 53.4963 min
# ----------
# Epoch 28/99, current lr=0.001
# train loss: 0.211425, val loss: 1.193386, accuracy: 72.92, time: 55.4035 min
# ----------
# Epoch 29/99, current lr=0.001
# train loss: 0.193672, val loss: 1.446258, accuracy: 70.33, time: 57.3045 min
# ----------
# Epoch 30/99, current lr=0.0001
# Copied best model weights!
# train loss: 0.093418, val loss: 0.947587, accuracy: 77.65, time: 59.1999 min
# ----------
# Epoch 31/99, current lr=0.0001
# Copied best model weights!
# train loss: 0.043676, val loss: 0.931833, accuracy: 78.19, time: 61.0868 min
# ----------
# Epoch 32/99, current lr=0.0001
# train loss: 0.032632, val loss: 0.932720, accuracy: 78.33, time: 62.9692 min
# ----------
# Epoch 33/99, current lr=0.0001
# Copied best model weights!
# train loss: 0.028624, val loss: 0.923838, accuracy: 78.77, time: 64.8590 min
# ----------
# Epoch 34/99, current lr=0.0001
# Copied best model weights!
# train loss: 0.026349, val loss: 0.917977, accuracy: 78.49, time: 66.7564 min
# ----------
# Epoch 35/99, current lr=0.0001
# train loss: 0.020335, val loss: 0.928785, accuracy: 78.62, time: 68.6537 min
# ----------
# Epoch 36/99, current lr=0.0001
# train loss: 0.020233, val loss: 0.925553, accuracy: 78.83, time: 70.5419 min
# ----------
# Epoch 37/99, current lr=0.0001
# train loss: 0.015262, val loss: 0.936011, accuracy: 78.74, time: 72.4127 min
# ----------
# Epoch 38/99, current lr=0.0001
# train loss: 0.015746, val loss: 0.928077, accuracy: 78.91, time: 74.2880 min
# ----------
# Epoch 39/99, current lr=0.0001
# train loss: 0.016812, val loss: 0.943751, accuracy: 78.89, time: 76.1735 min
# ----------
# Epoch 40/99, current lr=0.0001
# train loss: 0.011327, val loss: 0.949402, accuracy: 79.04, time: 78.0565 min
# ----------
# Epoch 41/99, current lr=0.0001
# train loss: 0.013518, val loss: 0.955317, accuracy: 78.57, time: 79.9496 min
# ----------
# Epoch 42/99, current lr=0.0001
# train loss: 0.010526, val loss: 0.979201, accuracy: 78.79, time: 81.8457 min
# ----------
# Epoch 43/99, current lr=0.0001
# train loss: 0.009777, val loss: 0.975093, accuracy: 78.84, time: 83.7589 min
# ----------
# Epoch 44/99, current lr=0.0001
# train loss: 0.009970, val loss: 0.982021, accuracy: 78.64, time: 85.6734 min
# ----------
# Epoch 45/99, current lr=0.0001
# train loss: 0.010334, val loss: 0.989328, accuracy: 78.85, time: 87.5669 min
# ----------
# Epoch 46/99, current lr=0.0001
# train loss: 0.007321, val loss: 0.978123, accuracy: 78.96, time: 89.4592 min
# ----------
# Epoch 47/99, current lr=0.0001
# train loss: 0.010508, val loss: 0.984120, accuracy: 78.66, time: 91.3636 min
# ----------
# Epoch 48/99, current lr=0.0001
# train loss: 0.008398, val loss: 0.989535, accuracy: 78.55, time: 93.2498 min
# ----------
# Epoch 49/99, current lr=0.0001
# train loss: 0.008599, val loss: 0.998239, accuracy: 78.46, time: 95.1357 min
# ----------
# Epoch 50/99, current lr=0.0001
# train loss: 0.009834, val loss: 1.012322, accuracy: 78.35, time: 97.0185 min
# ----------
# Epoch 51/99, current lr=0.0001
# train loss: 0.008323, val loss: 1.010515, accuracy: 78.56, time: 98.9050 min
# ----------
# Epoch 52/99, current lr=0.0001
# train loss: 0.007524, val loss: 1.010628, accuracy: 78.60, time: 100.7910 min
# ----------
# Epoch 53/99, current lr=0.0001
# train loss: 0.006103, val loss: 1.023910, accuracy: 78.75, time: 102.6667 min
# ----------
# Epoch 54/99, current lr=0.0001
# train loss: 0.008331, val loss: 1.012474, accuracy: 78.74, time: 104.5429 min
# ----------
# Epoch 55/99, current lr=0.0001
# train loss: 0.006927, val loss: 1.013648, accuracy: 78.95, time: 106.4352 min
# ----------
# Epoch 56/99, current lr=0.0001
# train loss: 0.006167, val loss: 1.008066, accuracy: 78.89, time: 108.3204 min
# ----------
# Epoch 57/99, current lr=0.0001
# train loss: 0.005524, val loss: 1.014507, accuracy: 78.76, time: 110.2080 min
# ----------
# Epoch 58/99, current lr=0.0001
# train loss: 0.005079, val loss: 1.057504, accuracy: 79.12, time: 112.0911 min
# ----------
# Epoch 59/99, current lr=0.0001
# train loss: 0.008026, val loss: 1.143957, accuracy: 77.84, time: 113.9835 min
# ----------
# Epoch 60/99, current lr=1e-05
# train loss: 0.009600, val loss: 1.074874, accuracy: 78.72, time: 115.8828 min
# ----------
# Epoch 61/99, current lr=1e-05
# train loss: 0.006653, val loss: 1.061642, accuracy: 78.49, time: 117.7787 min
# ----------
# Epoch 62/99, current lr=1e-05
# train loss: 0.007305, val loss: 1.055245, accuracy: 78.84, time: 119.6690 min
# ----------
# Epoch 63/99, current lr=1e-05
# train loss: 0.003976, val loss: 1.048329, accuracy: 79.00, time: 121.5620 min
# ----------
# Epoch 64/99, current lr=1e-05
# train loss: 0.005348, val loss: 1.043369, accuracy: 79.25, time: 123.4571 min
# ----------
# Epoch 65/99, current lr=1e-05
# train loss: 0.003977, val loss: 1.026907, accuracy: 79.03, time: 125.3404 min
# ----------
# Epoch 66/99, current lr=1e-05
# train loss: 0.003978, val loss: 1.044306, accuracy: 79.11, time: 127.2181 min
# ----------
# Epoch 67/99, current lr=1e-05
# train loss: 0.003718, val loss: 1.034661, accuracy: 79.53, time: 129.1032 min
# ----------
# Epoch 68/99, current lr=1e-05
# train loss: 0.004544, val loss: 1.029132, accuracy: 79.35, time: 130.9817 min
# ----------
# Epoch 69/99, current lr=1e-05
# train loss: 0.003800, val loss: 1.038374, accuracy: 79.24, time: 132.8509 min
# ----------
# Epoch 70/99, current lr=1e-05
# train loss: 0.004303, val loss: 1.048111, accuracy: 79.14, time: 134.7230 min
# ----------
# Epoch 71/99, current lr=1e-05
# train loss: 0.003090, val loss: 1.027705, accuracy: 79.33, time: 136.6094 min
# ----------
# Epoch 72/99, current lr=1e-05
# train loss: 0.003096, val loss: 1.031193, accuracy: 79.35, time: 138.5041 min
# ----------
# Epoch 73/99, current lr=1e-05
# train loss: 0.002419, val loss: 1.022570, accuracy: 79.26, time: 140.4042 min
# ----------
# Epoch 74/99, current lr=1e-05
# train loss: 0.002958, val loss: 1.052264, accuracy: 79.19, time: 142.2983 min
# ----------
# Epoch 75/99, current lr=1e-05
# train loss: 0.002898, val loss: 1.023056, accuracy: 79.50, time: 144.1961 min
# ----------
# Epoch 76/99, current lr=1e-05
# train loss: 0.003194, val loss: 1.050860, accuracy: 79.15, time: 146.0970 min
# ----------
# Epoch 77/99, current lr=1e-05
# train loss: 0.004747, val loss: 1.031520, accuracy: 79.30, time: 147.9910 min
# ----------
# Epoch 78/99, current lr=1e-05
# train loss: 0.002734, val loss: 1.039118, accuracy: 79.30, time: 149.8808 min
# ----------
# Epoch 79/99, current lr=1e-05
# train loss: 0.002998, val loss: 1.019381, accuracy: 79.33, time: 151.7792 min
# ----------
# Epoch 80/99, current lr=1e-05
# train loss: 0.002743, val loss: 1.057010, accuracy: 79.35, time: 153.6808 min
# ----------
# Epoch 81/99, current lr=1e-05
# train loss: 0.002910, val loss: 1.051487, accuracy: 79.01, time: 155.5748 min
# ----------
# Epoch 82/99, current lr=1e-05
# train loss: 0.002446, val loss: 1.035291, accuracy: 79.25, time: 157.4657 min
# ----------
# Epoch 83/99, current lr=1e-05
# train loss: 0.002392, val loss: 1.039811, accuracy: 79.25, time: 159.3473 min
# ----------
# Epoch 84/99, current lr=1e-05
# train loss: 0.002718, val loss: 1.050477, accuracy: 79.26, time: 161.2106 min
# ----------
# Epoch 85/99, current lr=1e-05
# train loss: 0.002256, val loss: 1.047867, accuracy: 79.35, time: 163.0843 min
# ----------
# Epoch 86/99, current lr=1e-05
# train loss: 0.002367, val loss: 1.033165, accuracy: 79.27, time: 164.9657 min
# ----------
# Epoch 87/99, current lr=1e-05
# train loss: 0.002654, val loss: 1.059887, accuracy: 79.10, time: 166.8439 min
# ----------
# Epoch 88/99, current lr=1e-05
# train loss: 0.003372, val loss: 1.057319, accuracy: 79.31, time: 168.7523 min
# ----------
# Epoch 89/99, current lr=1e-05
# train loss: 0.003345, val loss: 1.046337, accuracy: 79.38, time: 170.6320 min
# ----------
# Epoch 90/99, current lr=1.0000000000000002e-06
# train loss: 0.003102, val loss: 1.042387, accuracy: 79.00, time: 172.4985 min
# ----------
# Epoch 91/99, current lr=1.0000000000000002e-06
# train loss: 0.003174, val loss: 1.067155, accuracy: 79.15, time: 174.3631 min
# ----------
# Epoch 92/99, current lr=1.0000000000000002e-06
# train loss: 0.002178, val loss: 1.053207, accuracy: 79.36, time: 176.2144 min
# ----------
# Epoch 93/99, current lr=1.0000000000000002e-06
# train loss: 0.002265, val loss: 1.035722, accuracy: 79.42, time: 178.0495 min
# ----------
# Epoch 94/99, current lr=1.0000000000000002e-06
# train loss: 0.003772, val loss: 1.064000, accuracy: 79.45, time: 179.8816 min
# ----------
# Epoch 95/99, current lr=1.0000000000000002e-06
# train loss: 0.002247, val loss: 1.056660, accuracy: 79.17, time: 181.7230 min
# ----------
# Epoch 96/99, current lr=1.0000000000000002e-06
# train loss: 0.002069, val loss: 1.057605, accuracy: 79.25, time: 183.5634 min
# ----------
# Epoch 97/99, current lr=1.0000000000000002e-06
# train loss: 0.003117, val loss: 1.055963, accuracy: 79.38, time: 185.4005 min
# ----------
# Epoch 98/99, current lr=1.0000000000000002e-06
# train loss: 0.002694, val loss: 1.049937, accuracy: 79.24, time: 187.2398 min
# ----------
# Epoch 99/99, current lr=1.0000000000000002e-06
# train loss: 0.002338, val loss: 1.027131, accuracy: 79.50, time: 189.0876 min
# ----------

# %%
# Train-Validation Progress
num_epochs=params_train["num_epochs"]

# plot loss progress
plt.title("Train-Val Loss")
plt.plot(range(1,num_epochs+1),loss_hist["train"],label="train")
plt.plot(range(1,num_epochs+1),loss_hist["val"],label="val")
plt.ylabel("Loss")
plt.xlabel("Training Epochs")
plt.legend()
plt.show()

# plot accuracy progress
plt.title("Train-Val Accuracy")
plt.plot(range(1,num_epochs+1),metric_hist["train"],label="train")
plt.plot(range(1,num_epochs+1),metric_hist["val"],label="val")
plt.ylabel("Accuracy")
plt.xlabel("Training Epochs")
plt.legend()
plt.show()
